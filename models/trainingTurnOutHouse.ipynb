# %% [markdown]
# # Trainning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import h2o

# %%
df = pd.read_csv('final_dataframe.csv')

df['Native People'] = df['Native People'].astype(str).str.replace(',', '').astype(int)
df['Unemployment Rate'] = df['Unemployment Rate'].astype(str).str.replace(',', '').astype(float)
df['Mean household income'] = df['Mean household income'].astype(str).str.replace(',', '').astype(int)
df['Families income below poverty'] = df['Families income below poverty'].astype(str).str.replace(',', '').astype(float)
df['Graduate or professional degree'] = df['Graduate or professional degree'].astype(str).str.replace(',', '').astype(float)
df['Hispanic'] = df['Hispanic'].astype(str).str.replace(',', '').astype(int)
df['Male'] = df['Male'].astype(str).str.replace(',', '').astype(int)
df['Female'] = df['Female'].astype(str).str.replace(',', '').astype(int)

df.head()
# Out:
#   district  senate_candidate1  senate_candidate2  senate_total_votes  \
# 0     AL 7             920478            1392076             2316445
# 1     AK 0             146068              16806              354587
# 2     AZ 1                 28            1637661             3355307
# 3     AR 2             399390             793871             1193261
# 4    CA 50            6019422            5093942            11113364
#
#    house_democrat  house_republican  house_total_votes  presidential_democrat  \
# 0        123233.0             67416             193940                 849624
# 1        128553.0             67866             263610                 153778
# 2        179141.0            182336             361477                1672143
# 3         86887.0            147975             246446                 423932
# 4        168816.0             99819             268635               11110250
#
#    presidential_republican  presidential_total_votes  Native People  \
# 0                  1441170                   2323282         688852
# 1                   189951                    359530         678835
# 2                  1661686                   3387326         700868
# 3                   760647                   1219069         742344
# 4                  6006429                  17500881         607938
#
#    Unemployment Rate  Mean household income  Families income below poverty  \
# 0                6.2                  68392                           17.1
# 1                4.8                 114201                            7.2
# 2                3.6                 146662                            6.2
# 3                3.1                  89344                           10.2
# 4                4.3                 163873                            5.2
#
#    Graduate or professional degree  Hispanic    Male  Female  \
# 0                          44204.0    715132  338340  376792
# 1                          60116.0    733406  385855  347551
# 2                         123560.0    804256  393913  410343
# 3                          67783.0    774027  375240  398787
# 4                         149338.0    781251  391721  389530
#
#    18 years and over
# 0          3975209.0
# 1           559040.0
# 2          5964147.0
# 3          2394060.0
# 4         33715916.0

# %%
# Initialize H2O
h2o.init()

# Set the response column and predictor columns
df['house_votes_ratio'] = df['house_total_votes'] / (df['18 years and over'])
response = 'house_votes_ratio'
predictors = ['Native People', 'Unemployment Rate', 'Mean household income', 'Families income below poverty', 'Graduate or professional degree', 'Hispanic', 'Male', 'Female']

# Convert the pandas dataframe to H2OFrame
h2o_df = h2o.H2OFrame(df)

# Split the data into train and test sets
train, test = h2o_df.split_frame(ratios=[0.8], seed=1234)

# Run AutoML
aml = h2o.automl.H2OAutoML(max_runtime_secs=3600, seed=1234)
aml.train(x=predictors, y=response, training_frame=train)

# View the AutoML Leaderboard
lb = aml.leaderboard
print(lb)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         14 hours 52 mins
# H2O_cluster_timezone:       America/Chicago
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.5
# H2O_cluster_version_age:    2 months and 26 days
# H2O_cluster_name:           H2O_from_python_alonm_pcu84r
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    2.205 Gb
# H2O_cluster_total_cores:    16
# H2O_cluster_allowed_cores:  16
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.12.5 final
# --------------------------  -----------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |█
# 08:05:03.619: AutoML: XGBoost is not available; skipping it.
# 08:05:03.725: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 36.0.
#
# ██████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     rmse         mse        mae      rmsle    mean_residual_deviance
# DeepLearning_grid_2_AutoML_4_20241125_80503_model_73    0.0935282  0.00874752  0.0693171  0.0771767                0.00874752
# StackedEnsemble_Best1000_1_AutoML_4_20241125_80503      0.0980313  0.00961013  0.0643615  0.0799147                0.00961013
# DeepLearning_grid_3_AutoML_4_20241125_80503_model_90    0.0981389  0.00963124  0.0740107  0.080371                 0.00963124
# StackedEnsemble_BestOfFamily_4_AutoML_4_20241125_80503  0.0992917  0.00985884  0.0669397  0.0808351                0.00985884
# DeepLearning_grid_2_AutoML_4_20241125_80503_model_85    0.0994971  0.00989967  0.065995   0.0813039                0.00989967
# StackedEnsemble_AllModels_6_AutoML_4_20241125_80503     0.0995888  0.00991793  0.0653323  0.0815435                0.00991793
# DeepLearning_grid_3_AutoML_4_20241125_80503_model_45    0.101362   0.0102744   0.0691162  0.0830176                0.0102744
# DeepLearning_grid_2_AutoML_4_20241125_80503_model_72    0.101546   0.0103117   0.0684069  0.0826905                0.0103117
# StackedEnsemble_BestOfFamily_6_AutoML_4_20241125_80503  0.101595   0.0103216   0.0682523  0.0825779                0.0103216
# DeepLearning_grid_3_AutoML_4_20241125_80503_model_96    0.102389   0.0104834   0.0745499  0.0841157                0.0104834
# [583 rows x 6 columns]

# %%
import os

# Create the directory if it doesn't exist
output_dir = 'house_turnout_autoML'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Save the top 10 models
for i in range(10):
    model = h2o.get_model(lb[i, 'model_id'])
    model_path = h2o.save_model(model=model, path=output_dir, force=True)
    print(f"Model {i+1} saved to: {model_path}")
# Out:
# Model 1 saved to: C:\Users\alonm\Documents\IIT\Fall semester\Online social network analysis\Project\Online-Social-Network-Analysis-Election-Prediction\house_turnout_autoML\DeepLearning_grid_2_AutoML_4_20241125_80503_model_73
# Model 2 saved to: C:\Users\alonm\Documents\IIT\Fall semester\Online social network analysis\Project\Online-Social-Network-Analysis-Election-Prediction\house_turnout_autoML\StackedEnsemble_Best1000_1_AutoML_4_20241125_80503
# Model 3 saved to: C:\Users\alonm\Documents\IIT\Fall semester\Online social network analysis\Project\Online-Social-Network-Analysis-Election-Prediction\house_turnout_autoML\DeepLearning_grid_3_AutoML_4_20241125_80503_model_90
# Model 4 saved to: C:\Users\alonm\Documents\IIT\Fall semester\Online social network analysis\Project\Online-Social-Network-Analysis-Election-Prediction\house_turnout_autoML\StackedEnsemble_BestOfFamily_4_AutoML_4_20241125_80503
# Model 5 saved to: C:\Users\alonm\Documents\IIT\Fall semester\Online social network analysis\Project\Online-Social-Network-Analysis-Election-Prediction\house_turnout_autoML\DeepLearning_grid_2_AutoML_4_20241125_80503_model_85
# Model 6 saved to: C:\Users\alonm\Documents\IIT\Fall semester\Online social network analysis\Project\Online-Social-Network-Analysis-Election-Prediction\house_turnout_autoML\StackedEnsemble_AllModels_6_AutoML_4_20241125_80503
# Model 7 saved to: C:\Users\alonm\Documents\IIT\Fall semester\Online social network analysis\Project\Online-Social-Network-Analysis-Election-Prediction\house_turnout_autoML\DeepLearning_grid_3_AutoML_4_20241125_80503_model_45
# Model 8 saved to: C:\Users\alonm\Documents\IIT\Fall semester\Online social network analysis\Project\Online-Social-Network-Analysis-Election-Prediction\house_turnout_autoML\DeepLearning_grid_2_AutoML_4_20241125_80503_model_72
# Model 9 saved to: C:\Users\alonm\Documents\IIT\Fall semester\Online social network analysis\Project\Online-Social-Network-Analysis-Election-Prediction\house_turnout_autoML\StackedEnsemble_BestOfFamily_6_AutoML_4_20241125_80503
# Model 10 saved to: C:\Users\alonm\Documents\IIT\Fall semester\Online social network analysis\Project\Online-Social-Network-Analysis-Election-Prediction\house_turnout_autoML\DeepLearning_grid_3_AutoML_4_20241125_80503_model_96

# %%
# Filter the test dataset for district CA 50
district_ca50 = df[df['district'] == 'CA 50']

# Convert the filtered dataset to H2OFrame
district_ca50_h2o = h2o.H2OFrame(district_ca50)

# Use the top 10 models to make predictions on the filtered dataset
for i in range(10):
    model = h2o.get_model(lb[i, 'model_id'])
    predictions = model.predict(district_ca50_h2o)
    print(f"Predictions from model {i+1}:")
    print(predictions)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# deeplearning prediction progress: |██████████████████████████████████████████████| (done) 100%
# Predictions from model 1:
#   predict
#  0.033431
# [1 row x 1 column]
#
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Predictions from model 2:
#   predict
# 0.0408617
# [1 row x 1 column]
#
# deeplearning prediction progress: |██████████████████████████████████████████████| (done) 100%
# Predictions from model 3:
#   predict
# 0.0909555
# [1 row x 1 column]
#
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Predictions from model 4:
#   predict
# 0.0437304
# [1 row x 1 column]
#
# deeplearning prediction progress: |██████████████████████████████████████████████| (done) 100%
# Predictions from model 5:
#   predict
# 0.0410149
# [1 row x 1 column]
#
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Predictions from model 6:
#   predict
# 0.0518455
# [1 row x 1 column]
#
# deeplearning prediction progress: |██████████████████████████████████████████████| (done) 100%
# Predictions from model 7:
#     predict
# -0.00127969
# [1 row x 1 column]
#
# deeplearning prediction progress: |██████████████████████████████████████████████| (done) 100%
# Predictions from model 8:
#   predict
#   0.09858
# [1 row x 1 column]
#
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Predictions from model 9:
#   predict
# 0.0520668
# [1 row x 1 column]
#
# deeplearning prediction progress: |██████████████████████████████████████████████| (done) 100%
# Predictions from model 10:
#   predict
# 0.0808201
# [1 row x 1 column]
